# %% [markdown]
# # Big Mountains in North America

# %% [markdown]
# We want to find the list of mountains in North America with a prominence of at least 2000 m and an isolation of at least 100 km.

# %% [markdown]
# ## Preparations

# %% [markdown]
# Import necessary packages.

# %%
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import matplotlib
import matplotlib.pyplot as plt
import csv

# %matplotlib inline

# %% [markdown]
# Connect to the correct webpage.

# %%
URL = "https://en.wikipedia.org/wiki/List_of_Ultras_of_North_America"

# %% [markdown]
# Get user agent etc.

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/109.0",
          "Accept-Encoding": "gzip, deflate",
           "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8",
          "DNT": "1", "Connection": "close", "Upgrade-Insecure-Requests":"1"}

# %% [markdown]
# ## Getting the data from the Wikipedia page.

# %% [markdown]
# Get html code of the webpage.

# %%
page = requests.get(URL, headers = headers)
soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

# %% [markdown]
# Let's see if we have the right page.

# %%
print(soup2.title.string)
# Out:
#    List of Ultras of North America - Wikipedia

# %% [markdown]
# Now we find the data that we are looking for, namely the table of ultras in North America.

# %%
NAultrashtml = soup2.find_all("table")[-4]
NAultrasdf = pd.read_html(str(NAultrashtml))[0]
NAultrasdf = NAultrasdf.drop("Rank", axis = 1)
display(NAultrasdf.head(5))
print(f'There are {NAultrasdf["Isolation"].isna().sum()} NaNs in the Isolation column.')
# Out:
#                               Mountain peak            Region  \
# 0                               Denali  [l]            Alaska
# 1                          Mount Logan  [m]             Yukon
# 2  Pico de Orizaba  [n]  (  Citlaltépetl  )  Puebla  Veracruz
# 3                   Mount Rainier  [o]  [p]        Washington
# 4                     Volcán Tajumulco  [q]         Guatemala
#
#             Mountain range  Elevation Prominence Isolation  \
# 0             Alaska Range  20,310 ft  20,146 ft       NaN
# 1    Saint Elias Mountains  19,541 ft  17,215 ft    387 mi
# 2  Cordillera Neovolcanica  18,491 ft  16,148 ft       NaN
# 3            Cascade Range  14,417 ft  13,210 ft       NaN
# 4      Sierra de las Nubes  13,845 ft  13,091 ft    448 mi
#
#                                             Location
# 0  .mw-parser-output .geo-default,.mw-parser-outp...
# 1  60°34′02″N  140°24′20″W  ﻿ / ﻿  60.5671°N 140....
# 2  19°01′50″N  97°16′11″W  ﻿ / ﻿  19.0305°N 97.26...
# 3  46°51′10″N  121°45′37″W  ﻿ / ﻿  46.8529°N 121....
# 4  15°02′35″N  91°54′13″W  ﻿ / ﻿  15.0430°N 91.90...
# There are 8 NaNs in the Isolation column.

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# We see that there are 8 NaNs in the isolation column. That number is low enough to fix it by hand. We also want to clean up the columns a bit.

# %%
NAultrasdf = NAultrasdf.astype({"Mountain peak": "string", "Region": "string", "Mountain range": "string"})

for i in range(len(NAultrasdf["Mountain peak"])):
    for char in ["[", "("]:
        if char in NAultrasdf["Mountain peak"][i]:
            NAultrasdf["Mountain peak"][i] = NAultrasdf["Mountain peak"][i][0: NAultrasdf["Mountain peak"][i].find(char)-2]
            # NAultrasdf.loc[:,("Mountain peak",i)] = NAultrasdf["Mountain peak"][i][0: NAultrasdf["Mountain peak"][i].find(char)-2]

x = []
for i in range(len(NAultrasdf["Isolation"])):
    if NAultrasdf["Isolation"].isna()[i]:
        x.append(i)

km_to_mi = 1/1.60924
ft_to_m = 0.3048

y = [7450.24, 2690.14, 1176.72, 3254.13, 2649.47, 1079.15, 1318.95, 1913.49]

for i in range(len(x)):
    NAultrasdf["Isolation"][x[i]] = " ".join((str(round(y[i]*km_to_mi)),"mi"))

for x in ["Elevation","Prominence"]:
    for i in range(len(NAultrasdf[x])):
        NAultrasdf[x][i] = round(float("".join((NAultrasdf[x][i][0:-7], NAultrasdf[x][i][-6:-3])))*ft_to_m)
        NAultrasdf[x]

for i in range(len(NAultrasdf["Isolation"])):
    NAultrasdf["Isolation"][i] = round(float(NAultrasdf["Isolation"][i][0:-3])/km_to_mi)



NAultrasdf.rename(columns = {"Elevation": "Elevation in m", "Prominence": "Prominence in m", "Isolation": "Isolation in km"}, inplace = True)

for i in range(len(NAultrasdf["Location"])):
    NAultrasdf["Location"][i] = str(NAultrasdf["Location"][i]).split(" ")[-2:]
    NAultrasdf["Location"][i] = ", ".join((str(NAultrasdf["Location"][i][0][0:-2]), str("".join(("-", NAultrasdf["Location"][i][1][0:-2])))))
    NAultrasdf["Location"][i] = "".join(("(", NAultrasdf["Location"][i], ")"))

display(NAultrasdf)
# Out:
#                    Mountain peak                     Region  \
# 0                         Denali                     Alaska
# 1                    Mount Logan                      Yukon
# 2                Pico de Orizaba           Puebla  Veracruz
# 3                  Mount Rainier                 Washington
# 4               Volcán Tajumulco                  Guatemala
# ..                           ...                        ...
# 348                 Mount Joffre  Alberta  British Columbia
# 349  Sierra de Agalta High Point                   Honduras
# 350                 Kitlope Peak           British Columbia
# 351               Robertson Peak           British Columbia
# 352            Mount Van der Est           British Columbia
#
#               Mountain range Elevation in m Prominence in m Isolation in km  \
# 0               Alaska Range           6190            6141            7451
# 1      Saint Elias Mountains           5956            5247             623
# 2    Cordillera Neovolcanica           5636            4922            2691
# 3              Cascade Range           4394            4026            1176
# 4        Sierra de las Nubes           4220            3990             721
# ..                       ...            ...             ...             ...
# 348         Canadian Rockies           3433            1505              49
# 349         Sierra de Agalta           2335            1505             122
# 350          Coast Mountains           1950            1505              16
# 351          Coast Mountains           2252            1502              16
# 352          Coast Mountains           1801            1502              35
#
#                  Location
# 0    (63.0690, -151.0063)
# 1    (60.5671, -140.4055)
# 2     (19.0305, -97.2698)
# 3    (46.8529, -121.7604)
# 4     (15.0430, -91.9037)
# ..                    ...
# 348  (50.5285, -115.2069)
# 349   (14.9576, -85.9165)
# 350  (53.0381, -127.6414)
# 351  (49.6460, -122.2502)
# 352  (50.5565, -125.2832)
#
# [353 rows x 7 columns]

# %% [markdown]
# ## Selecting our mountains

# %% [markdown]
# We are interested in mountains with a prominence of at least 2000 meters and with an isolation of at least 100 km so let's pick those out.

# %%
NAbigmountainsdf = NAultrasdf[(NAultrasdf["Prominence in m"] >= 2000) & (NAultrasdf["Isolation in km"] >= 100)].set_index("Mountain peak")
print(f'There are {len(NAbigmountainsdf["Region"])} mountains in North America with a prominence of at least 2000 m and an isolation of at least 100 km, and they are listed in the table below.')
display(NAbigmountainsdf)
# Out:
# There are 57 mountains in North America with a prominence of at least 2000 m and an isolation of at least 100 km, and they are listed in the table below.
#                                           Region              Mountain range  \
# Mountain peak
# Denali                                    Alaska                Alaska Range
# Mount Logan                                Yukon       Saint Elias Mountains
# Pico de Orizaba                 Puebla  Veracruz     Cordillera Neovolcanica
# Mount Rainier                         Washington               Cascade Range
# Volcán Tajumulco                       Guatemala         Sierra de las Nubes
# Mount Fairweather       Alaska  British Columbia       Saint Elias Mountains
# Chirripó Grande                       Costa Rica     Cordillera de Talamanca
# Gunnbjørn Fjeld                        Greenland         Island of Greenland
# Mount Hayes                               Alaska                Alaska Range
# Mount Waddington                British Columbia             Coast Mountains
# Mount Marcus Baker                        Alaska           Chugach Mountains
# Pico Duarte                   Dominican Republic        Island of Hispaniola
# Mount Whitney                         California               Sierra Nevada
# Popocatépetl             México  Morelos  Puebla     Cordillera Neovolcanica
# Mount Shasta                          California               Cascade Range
# Shishaldin Volcano                        Alaska               Unimak Island
# Mount Robson                    British Columbia            Canadian Rockies
# Mount Elbert                            Colorado               Sawatch Range
# Nevado de Colima                         Jalisco     Cordillera Neovolcanica
# Mount Baker                           Washington                Skagit Range
# Mount Torbert                             Alaska                Alaska Range
# Pic la Selle                               Haiti        Island of Hispaniola
# Barbeau Peak                             Nunavut            Ellesmere Island
# San Gorgonio Mountain                 California    San Bernardino Mountains
# Charleston Peak                           Nevada            Spring Mountains
# Mount Pavlof                              Alaska            Alaska Peninsula
# Mount Veniaminof                          Alaska            Alaska Peninsula
# Skihist Mountain                British Columbia             Coast Mountains
# Mount Ratz                      British Columbia             Coast Mountains
# Mount Isto                                Alaska                Brooks Range
# Mount Olympus                         Washington           Olympic Mountains
# Mount Columbia         Alberta  British Columbia            Canadian Rockies
# Mount Tom White                           Alaska           Chugach Mountains
# Wheeler Peak                              Nevada                 Snake Range
# Ulysses Mountain                British Columbia               Muskwa Ranges
# Blue Mountain Peak                       Jamaica           Island of Jamaica
# Mount Griggs                              Alaska            Alaska Peninsula
# Nevado de Toluca                          México     Cordillera Neovolcanica
# Outlook Peak                             Nunavut         Axel Heiberg Island
# Golden Hinde                    British Columbia            Vancouver Island
# White Mountain Peak                   California             White Mountains
# Stauning Alper                         Greenland         Island of Greenland
# Cerro Teotepec                          Guerrero        Sierra Madre del Sur
# Keele Peak                                 Yukon         Mackenzie Mountains
# Cloud Peak                               Wyoming           Bighorn Mountains
# Gannett Peak                             Wyoming            Wind River Range
# Mount Vsevidof                            Alaska                Umnak Island
# Mount Odin                               Nunavut               Baffin Island
# Cerro el Nacimiento                       Oaxaca        Sierra Madre del Sur
# Picacho del Diablo               Baja California  Sierra de San Pedro Mártir
# Pic Macaya                                 Haiti        Island of Hispaniola
# Mount Assiniboine      Alberta  British Columbia            Canadian Rockies
# Mount Jancowski                 British Columbia             Coast Mountains
# Cerro Las Minas                         Honduras         Sierra de las Nubes
# Beitstad Peak                            Nunavut            Ellesmere Island
# Mount Chiginagak                          Alaska              Aleutian Range
# Perserajoq                             Greenland         Island of Greenland
#
#                       Elevation in m Prominence in m Isolation in km  \
# Mountain peak
# Denali                          6190            6141            7451
# Mount Logan                     5956            5247             623
# Pico de Orizaba                 5636            4922            2691
# Mount Rainier                   4394            4026            1176
# Volcán Tajumulco                4220            3990             721
# Mount Fairweather               4671            3961             200
# Chirripó Grande                 3819            3755             879
# Gunnbjørn Fjeld                 3694            3694            3254
# Mount Hayes                     4216            3507             202
# Mount Waddington                4019            3289             562
# Mount Marcus Baker              4016            3277             203
# Pico Duarte                     3098            3098             940
# Mount Whitney                   4421            3072            2649
# Popocatépetl                    5410            3040             143
# Mount Shasta                    4322            2979             539
# Shishaldin Volcano              2869            2869             877
# Mount Robson                    3959            2829             460
# Mount Elbert                    4401            2772            1080
# Nevado de Colima                4270            2720             406
# Mount Baker                     3288            2696             212
# Mount Torbert                   3479            2648             157
# Pic la Selle                    2674            2644             127
# Barbeau Peak                    2616            2616             797
# San Gorgonio Mountain           3506            2528             262
# Charleston Peak                 3632            2517             217
# Mount Pavlof                    2515            2499             152
# Mount Veniaminof                2507            2499             336
# Skihist Mountain                2968            2458             157
# Mount Ratz                      3090            2430             311
# Mount Isto                      2736            2408             634
# Mount Olympus                   2432            2389             174
# Mount Columbia                  3741            2371             158
# Mount Tom White                 3411            2329             117
# Wheeler Peak                    3982            2307             373
# Ulysses Mountain                3024            2294             436
# Blue Mountain Peak              2256            2256             273
# Mount Griggs                    2332            2225             218
# Nevado de Toluca                4690            2225             118
# Outlook Peak                    2210            2210             268
# Golden Hinde                    2197            2197             134
# White Mountain Peak             4344            2193             108
# Stauning Alper                  2831            2181             165
# Cerro Teotepec                  3550            2180             185
# Keele Peak                      2952            2161             542
# Cloud Peak                      4013            2157             233
# Gannett Peak                    4209            2157             467
# Mount Vsevidof                  2149            2149             359
# Mount Odin                      2143            2143             586
# Cerro el Nacimiento             3710            2140             330
# Picacho del Diablo              3095            2125             335
# Pic Macaya                      2347            2087             216
# Mount Assiniboine               3616            2082             142
# Mount Jancowski                 2729            2079             124
# Cerro Las Minas                 2849            2069             132
# Beitstad Peak                   2347            2044             354
# Mount Chiginagak                2111            2035             157
# Perserajoq                      2259            2009             528
#
#                                    Location
# Mountain peak
# Denali                 (63.0690, -151.0063)
# Mount Logan            (60.5671, -140.4055)
# Pico de Orizaba         (19.0305, -97.2698)
# Mount Rainier          (46.8529, -121.7604)
# Volcán Tajumulco        (15.0430, -91.9037)
# Mount Fairweather      (58.9064, -137.5265)
# Chirripó Grande          (9.4843, -83.4889)
# Gunnbjørn Fjeld         (68.9184, -29.8991)
# Mount Hayes            (63.6203, -146.7178)
# Mount Waddington       (51.3737, -125.2636)
# Mount Marcus Baker     (61.4374, -147.7525)
# Pico Duarte             (19.0231, -70.9977)
# Mount Whitney          (36.5786, -118.2920)
# Popocatépetl            (19.0225, -98.6278)
# Mount Shasta           (41.4092, -122.1949)
# Shishaldin Volcano     (54.7554, -163.9709)
# Mount Robson           (53.1105, -119.1566)
# Mount Elbert           (39.1178, -106.4454)
# Nevado de Colima       (19.5633, -103.6087)
# Mount Baker            (48.7768, -121.8145)
# Mount Torbert          (61.4086, -152.4125)
# Pic la Selle            (18.3602, -71.9767)
# Barbeau Peak            (81.9148, -75.0093)
# San Gorgonio Mountain  (34.0992, -116.8249)
# Charleston Peak        (36.2716, -115.6956)
# Mount Pavlof           (55.4173, -161.8932)
# Mount Veniaminof       (56.2194, -159.2975)
# Skihist Mountain       (50.1878, -121.9032)
# Mount Ratz             (57.3930, -132.3031)
# Mount Isto             (69.2025, -143.8020)
# Mount Olympus          (47.8013, -123.7108)
# Mount Columbia         (52.1473, -117.4416)
# Mount Tom White        (60.6518, -143.6972)
# Wheeler Peak           (38.9858, -114.3139)
# Ulysses Mountain       (57.3464, -124.0928)
# Blue Mountain Peak      (18.0465, -76.5788)
# Mount Griggs           (58.3534, -155.0958)
# Nevado de Toluca        (19.1020, -99.7677)
# Outlook Peak            (79.7397, -91.4061)
# Golden Hinde           (49.6627, -125.7470)
# White Mountain Peak    (37.6341, -118.2557)
# Stauning Alper          (72.1167, -24.9000)
# Cerro Teotepec         (17.4682, -100.1364)
# Keele Peak             (63.4314, -130.3243)
# Cloud Peak             (44.3821, -107.1739)
# Gannett Peak           (43.1842, -109.6542)
# Mount Vsevidof         (53.1256, -168.6938)
# Mount Odin              (66.5468, -65.4289)
# Cerro el Nacimiento     (16.2115, -96.1967)
# Picacho del Diablo     (30.9925, -115.3753)
# Pic Macaya              (18.3822, -74.0243)
# Mount Assiniboine      (50.8696, -115.6509)
# Mount Jancowski        (56.3372, -129.9817)
# Cerro Las Minas         (14.5340, -88.6804)
# Beitstad Peak           (78.8007, -79.5292)
# Mount Chiginagak       (57.1334, -156.9912)
# Perserajoq              (71.4000, -51.9667)

# %% [markdown]
# ## Visualisations

# %% [markdown]
# To make visualisations, we use Tableau Public, so we export our table as a csv file so we can read the data with Tableau.

# %%
NAbigmountainsdf.to_csv("NAbigmountains.csv")

# %% [markdown]
# Check out [this Tableau Public](https://public.tableau.com/app/profile/arjan.van.denzen/viz/BigMountainsNorthAmerica/Sheet1) page for a map containing these mountains and two other visualisations pertaining to these mountains. We create a csv file from the dataframe above to use in Tableau.

# %% [markdown]
# The data used in this notebook are collected and adapted from a Wikipedia page, so they fall under [this license](https://creativecommons.org/licenses/by-sa/3.0/). That means that this notebook also falls under the same license.
